# %%
import SeqStats as ss

# %%
seq = ss.readText('./data/dna.txt')

# %%
ss.seqInfo(seq)
# Out:
# Sequence Length: 1157 bp
# Frequency: {'T': 383, 'G': 198, 'C': 260, 'A': 316}
# Percentage: {'T': 0.33, 'G': 0.17, 'C': 0.22, 'A': 0.27}
# GC Content: 39.59
# AT Content: 60.41

# %%
ss.plotFrequency(seq, kind='bar')

# %%
ss.plotFrequency(seq, kind='pie')

# %%
ss.ntDensityOne(seq, windowsize=500)

# %%
seq = ss.readFASTA('./data/Haemophilus_influenzae.fasta')

# %%
ss.ntDensityOne(seq, windowsize=9000)

# %%
ss.ntDensityTwo(seq,  windowsize=9000)

# %%
ss.head(seq)
# Out:
# '...'

# %%
ss.tail(seq)
# Out:
# '...'

# %%
 dir(ss)
# Out:
# ['Counter',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__warningregistry__',
#  'buildKmers',
#  'calculateAT',
#  'calculateGC',
#  'countKmers',
#  'deque',
#  'frequency',
#  'head',
#  'myscatterplot',
#  'ntDensityOne',
#  'ntDensityTwo',
#  'plotFrequency',
#  'plotKmerFrequency',
#  'plotProteinFrequency',
#  'plotSubSeqAT',
#  'plotSubSeqGC',
#  'plt',
#  'proteinFrequency',
#  'readFASTA',
#  'readFASTQ',
#  'readText',
#  'seqInfo',
#  'subSeqAT',
#  'subSeqGC',
#  'tail']

# %%
kmers = ss.buildKmers(seq, 2)

# %%
ss.countKmers(kmers)
# Out:
# Counter({'AA': 223369,
#          'AC': 93850,
#          'CC': 69297,
#          'CG': 73364,
#          'GA': 94221,
#          'AT': 169804,
#          'TT': 221014,
#          'TA': 134844,
#          'CA': 123643,
#          'AG': 89055,
#          'GT': 92435,
#          'TG': 120812,
#          'GC': 96575,
#          'GG': 66249,
#          'TC': 97113,
#          'CT': 90530})

# %%
ss.plotKmerFrequency(kmers, kind='bar', title="Kmer Frequency Disytribution", xlab="Kmers", ylab="Frequency")

# %%
ss.plotSubSeqGC(seq)
